# %%
### Use this notebook to test different tools and other quick functions.

# %%
from pathlib import Path
from tools.converter import numbers_to_csv

in_file = Path("/workspaces/campus-burglary-risk-prediction/campus_burglary_risk_prediction_v2/data/external/APD_DATA_20:24.numbers")
out_file = Path("/workspaces/campus-burglary-risk-prediction/campus_burglary_risk_prediction_v2/data/external/APD_DATA_20:24.csv")

numbers_to_csv(in_file, out_file)
