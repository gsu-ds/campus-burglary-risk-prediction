# %%
import wandb
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

api = wandb.Api()

ENTITY = "joshuadariuspina-georgia-state-university"

PROJECTS = [
    "rolling-cv",
    "campus-burglary-risk",
    "updated_burglary_forecast",
    "atl-crime-hourly-forecast",
    "atl-crime-risk"
]

all_rows = []

for project in PROJECTS:
    print(f"Fetching project → {project}")
    runs = api.runs(f"{ENTITY}/{project}")
    
    for r in runs:
        all_rows.append({
            "project": project,
            "run_id": r.id,
            "model": r.config.get("model"),
            "dataset": r.config.get("dataset"),
            "MAE": r.summary.get("Mean_MAE"),
            "RMSE": r.summary.get("Mean_RMSE"),
            "R2": r.summary.get("Mean_R2"),
            "MAPE": r.summary.get("Mean_MAPE"),
            "timestamp": r.created_at,
            "url": r.url,
        })

df_all = pd.DataFrame(all_rows)
print(f"\nLoaded {len(df_all)} W&B runs.")
df_all.head()
# Out:
# Fetching project → rolling-cv
# Fetching project → campus-burglary-risk
# Fetching project → updated_burglary_forecast
# Fetching project → atl-crime-hourly-forecast
# Fetching project → atl-crime-risk
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=19 sec). Create a new API with an integer timeout larger than 19, e.g., `api = wandb.Api(timeout=29)` to increase the graphql timeout.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 28
#      22     runs = api.runs(f"{ENTITY}/{project}")
#      24     for r in runs:
#      25         all_rows.append({
#      26             "project": project,
#      27             "run_id": r.id,
# ---> 28             "model": r.config.get("model"),
#      29             "dataset": r.config.get("dataset"),
#      30             "MAE": r.summary.get("Mean_MAE"),
#      31             "RMSE": r.summary.get("Mean_RMSE"),
#      32             "R2": r.summary.get("Mean_R2"),
#      33             "MAPE": r.summary.get("Mean_MAPE"),
#      34             "timestamp": r.created_at,
#      35             "url": r.url,
#      36         })
#      38 df_all = pd.DataFrame(all_rows)
#      39 print(f"\nLoaded {len(df_all)} W&B runs.")
#
# File /workspaces/campus-burglary-risk-prediction/dsci_env/lib/python3.12/site-packages/wandb/apis/public/runs.py:1310, in Run.config(self)
#    1308 """Get run config. Auto-loads full data if in lazy mode."""
#    1309 if self._lazy and not self._full_data_loaded and "config" not in self._attrs:
# -> 1310     self.load_full_data()
#    1312 # Ensure config is always converted to dict (defensive against conversion issues)
#    1313 config_value = self._attrs.get("config", {})
#
# File /workspaces/campus-burglary-risk-prediction/dsci_env/lib/python3.12/site-packages/wandb/apis/public/runs.py:1302, in Run.load_full_data(self, force)
#    1299     return self._attrs
#    1301 # Load full data and mark as loaded
# -> 1302 result = self._load_with_fragment(RUN_FRAGMENT, RUN_FRAGMENT_NAME, force=True)
#    1303 self._full_data_loaded = True
#    1304 return result
#
# File /workspaces/campus-burglary-risk-prediction/dsci_env/lib/python3.12/site-packages/wandb/apis/public/runs.py:730, in Run._load_with_fragment(self, fragment, fragment_name, force)
#     724 response = self._exec(query)
#     725 if (
#     726     response is None
#     727     or response.get("project") is None
#     728     or response["project"].get("run") is None
#     729 ):
# --> 730     raise ValueError("Could not find run {}".format(self))
#     731 self._attrs = response["project"]["run"]
#     733 self._state = self._attrs["state"]
#
# ValueError: Could not find run <Run joshuadariuspina-georgia-state-university/atl-crime-risk/n5970v4m (finished)>

# %%
leaderboard_full = (
    df_all.dropna(subset=["MAE"])
         .sort_values("MAE")
         .reset_index(drop=True)
)

display(leaderboard_full)
# Out:
#         project    run_id              model           dataset       MAE  \
# 0    rolling-cv  cky70tbu  CatBoostRegressor   npu_dense_panel  0.006253
# 1    rolling-cv  8tsbfhfx  CatBoostRegressor   npu_dense_panel  0.006253
# 2    rolling-cv  wfcwxyrw       RandomForest   npu_dense_panel  0.006975
# 3    rolling-cv  g77jgpsi       RandomForest   npu_dense_panel  0.006975
# 4    rolling-cv  6s1jtfv7       XGBRegressor   npu_dense_panel  0.007885
# ..          ...       ...                ...               ...       ...
# 140  rolling-cv  thixsfmz          NaiveMean              None  0.236910
# 141  rolling-cv  ons8o30y          NaiveMean              None  0.236910
# 142  rolling-cv  19sezlcz          NaiveMean              None  0.236910
# 143  rolling-cv  ob8cdkny          NaiveMean              None  0.236910
# 144  rolling-cv  9qcauyne       BaselineMean  npu_sparse_panel  0.236910
#
#          RMSE        R2          MAPE             timestamp  \
# 0    0.061313  0.970875  1.290952e+06  2025-12-02T18:55:56Z
# 1    0.061313  0.970875  1.290952e+06  2025-12-02T14:32:11Z
# 2    0.069141  0.962950  4.709259e-01  2025-12-02T14:28:15Z
# 3    0.069141  0.962950  4.709259e-01  2025-12-02T18:50:47Z
# 4    0.069354  0.962676  5.802362e+06  2025-12-02T14:29:03Z
# ..        ...       ...           ...                   ...
# 140  0.410422 -0.000653  1.719934e+01  2025-12-02T11:34:41Z
# 141  0.410422 -0.000653  1.719934e+01  2025-12-02T11:31:16Z
# 142  0.410422 -0.000653  1.719934e+01  2025-12-02T11:37:59Z
# 143  0.410422 -0.000653  1.719934e+01  2025-12-02T11:41:19Z
# 144  0.410422 -0.000653  1.719934e+01  2025-12-02T18:44:43Z
#
#                                                    url
# 0    https://wandb.ai/joshuadariuspina-georgia-stat...
# 1    https://wandb.ai/joshuadariuspina-georgia-stat...
# 2    https://wandb.ai/joshuadariuspina-georgia-stat...
# 3    https://wandb.ai/joshuadariuspina-georgia-stat...
# 4    https://wandb.ai/joshuadariuspina-georgia-stat...
# ..                                                 ...
# 140  https://wandb.ai/joshuadariuspina-georgia-stat...
# 141  https://wandb.ai/joshuadariuspina-georgia-stat...
# 142  https://wandb.ai/joshuadariuspina-georgia-stat...
# 143  https://wandb.ai/joshuadariuspina-georgia-stat...
# 144  https://wandb.ai/joshuadariuspina-georgia-stat...
#
# [145 rows x 10 columns]

# %%
leaderboard_by_model = (
    df_all.groupby("model")[["MAE","RMSE","R2"]]
          .mean()
          .sort_values("MAE")
)

display(leaderboard_by_model)
# Out:
#                                                      MAE      RMSE        R2
# model
# CatBoostRegressor                               0.035541  0.127744  0.873449
# RandomForest                                    0.068190  0.205952  0.734632
# CatBoost                                        0.072184  0.205518  0.749199
# XGBRegressor                                    0.073205  0.206664  0.733748
# LinearRegression                                0.120347  0.262256  0.465253
# NaiveLastHour                                   0.164721  0.460898 -0.277544
# BaselineMean                                    0.217292  0.384938 -0.000430
# SeasonalWeekly                                  0.218504  0.411096 -0.006095
# PoissonGLM                                      0.219837  0.399519  0.051728
# NaiveMean                                       0.236910  0.410422 -0.000653
# xgboost-multiclass                                   NaN       NaN       NaN
# xgboost-multiclass + class_weight                    NaN       NaN       NaN
# xgboost-multiclass + class_weight (leak-proof)       NaN       NaN       NaN

# %%
leaderboard_by_data = (
    df_all.groupby("dataset")[["MAE","RMSE","R2"]]
          .mean()
          .sort_values("MAE")
)

display(leaderboard_by_data)
# Out:
#                                                  MAE      RMSE        R2
# dataset
# npu_dense_panel                             0.048080  0.136824  0.755128
# npu_sparse_panel                            0.134009  0.288706  0.450535
# data/processed/apd/npu_dense_panel.parquet       NaN       NaN       NaN

# %%
best_per_project = df_all.loc[
    df_all.groupby("project")["MAE"].idxmin()
]

display(best_per_project)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 best_per_project = df_all.loc[
#       2     df_all.groupby("project")["MAE"].idxmin()
#       3 ]
#       5 display(best_per_project)
#
# File /workspaces/campus-burglary-risk-prediction/dsci_env/lib/python3.12/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /workspaces/campus-burglary-risk-prediction/dsci_env/lib/python3.12/site-packages/pandas/core/indexing.py:1421, in _LocIndexer._getitem_axis(self, key, axis)
#    1418     if hasattr(key, "ndim") and key.ndim > 1:
#    1419         raise ValueError("Cannot index with multidimensional key")
# -> 1421     return self._getitem_iterable(key, axis=axis)
#    1423 # nested tuple slicing
#    1424 if is_nested_tuple(key, labels):
#
# File /workspaces/campus-burglary-risk-prediction/dsci_env/lib/python3.12/site-packages/pandas/core/indexing.py:1361, in _LocIndexer._getitem_iterable(self, key, axis)
#    1358 self._validate_key(key, axis)
#    1360 # A collection of keys
# -> 1361 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1362 return self.obj._reindex_with_indexers(
#    1363     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1364 )
#
# File /workspaces/campus-burglary-risk-prediction/dsci_env/lib/python3.12/site-packages/pandas/core/indexing.py:1559, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1556 ax = self.obj._get_axis(axis)
#    1557 axis_name = self.obj._get_axis_name(axis)
# -> 1559 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1561 return keyarr, indexer
#
# File /workspaces/campus-burglary-risk-prediction/dsci_env/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File /workspaces/campus-burglary-risk-prediction/dsci_env/lib/python3.12/site-packages/pandas/core/indexes/base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: '[nan] not in index'

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df_all,
    x="MAE",
    y="RMSE",
    hue="project",
    style="model",
    s=120
)
plt.title("Performance Comparison Across Projects")
plt.show()

# %%
leaderboard_full.to_csv("leaderboard_full.csv", index=False)
leaderboard_by_model.to_csv("leaderboard_by_model.csv")
leaderboard_by_data.to_csv("leaderboard_by_dataset.csv")
best_per_project.to_csv("best_per_project.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 leaderboard_by_model.to_csv("leaderboard_by_model.csv")
#       3 leaderboard_by_data.to_csv("leaderboard_by_dataset.csv")
# ----> 4 best_per_project.to_csv("best_per_project.csv", index=False)
#
# NameError: name 'best_per_project' is not defined
